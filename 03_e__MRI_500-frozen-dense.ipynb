# %%
# MRI STUFF
# Test increase in layers 
# Increase in layer architectures
# Increase in drop out 
# With class weights, without class weights

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras import datasets, layers, models
from sklearn.metrics import (classification_report, confusion_matrix, balanced_accuracy_score, 
accuracy_score, roc_auc_score, auc)
from sklearn.model_selection import KFold, StratifiedKFold
import plotly.graph_objects as go
import glob

# %%
#drive.mount('/content/drive')

#ROOT_DIR = "/content/drive/MyDrive/Spring 2022/DTSC 870/Code" # HC Directory
#ROOT_DIR = "/content/drive/MyDrive/DTSC 870/Code" #MT Directory
KAGGLE_START = "/kaggle/input"
ROOT_DIR = KAGGLE_START
DATASET_01_TEST = KAGGLE_START + "/mri-test-set/test"
DATASET_01_TRAIN = KAGGLE_START + "/mri-trainset/train"
KAGGLE_OUT = "/kaggle/working"

# %%
datagen = ImageDataGenerator()
image_size = (256, 256)
test_set = datagen.flow_from_directory(DATASET_01_TEST, target_size=image_size, batch_size=32, class_mode='binary', shuffle=False)
train_set = datagen.flow_from_directory(DATASET_01_TRAIN, target_size=image_size, batch_size=32, class_mode='binary')
# Out:
# Found 121 images belonging to 2 classes.
# Found 279 images belonging to 2 classes.

# %%
def create_model_V1():
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
  model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Dropout(0.4))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Dropout(0.4))
  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  #model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu'))
  model.add(layers.Dense(1, activation='sigmoid'))
  return model

# %%
def create_model_V1_02():
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  #model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu'))
  model.add(layers.Dense(1, activation='sigmoid'))
  return model

# %%
def create_model_V1_04():
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  #model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Flatten())
  model.add(layers.Dense(128, activation='relu'))
  model.add(layers.Dense(1, activation='sigmoid'))
  return model

# %%
def create_model_V2():
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
  model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Dropout(0.4))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  #model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Dropout(0.4))
  #model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  #model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Flatten())
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(1, activation='sigmoid'))
  return model

# %%
def create_model_V2_02():
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  #model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Dropout(0.4))
  #model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  #model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Flatten())
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(1, activation='sigmoid'))
  return model

# %%
def create_model_V2_04():
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  #model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Dropout(0.4))
  #model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  #model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Flatten())
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(1, activation='sigmoid'))
  return model

# %%
def create_model_V3():
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
  model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Dropout(0.4))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Dropout(0.4))
  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Conv2D(256, (3, 3), activation='relu'))
  model.add(layers.Flatten())
  model.add(layers.Dense(256, activation='relu'))
  model.add(layers.Dense(1, activation='sigmoid'))
  return model

# %%
def create_model_V3_02():
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2))
  #model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Conv2D(256, (3, 3), activation='relu'))
  model.add(layers.Flatten())
  model.add(layers.Dense(256, activation='relu'))
  model.add(layers.Dense(1, activation='sigmoid'))
  return model

# %%
def create_model_V3_04():
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  #model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Conv2D(256, (3, 3), activation='relu'))
  model.add(layers.Flatten())
  model.add(layers.Dense(256, activation='relu'))
  model.add(layers.Dense(1, activation='sigmoid'))
  return model

# %%
def create_model_V4():
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
  model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Dropout(0.4))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Dropout(0.4))
  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Conv2D(256, (3, 3), activation='relu'))
  model.add(layers.Flatten())
  model.add(layers.Dense(256, activation='relu'))
  model.add(layers.Dense(1, activation='sigmoid'))
  return model

# %%
def create_model_V4_02():
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Conv2D(256, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Conv2D(512, (3, 3), activation='relu'))
  model.add(layers.Flatten())
  model.add(layers.Dense(1024, activation='relu'))
  model.add(layers.Dense(1, activation='sigmoid'))
  return model

# %%
def create_model_V4_04():
  model = models.Sequential()
  model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  model.add(layers.Dropout(0.4))
  model.add(layers.Conv2D(128, (3, 3), activation='relu'))
  model.add(layers.MaxPooling2D((2, 2)))
  #model.add(layers.Conv2D(64, (3, 3), activation='relu'))
  model.add(layers.Conv2D(256, (3, 3), activation='relu'))
  model.add(layers.Flatten())
  model.add(layers.Dense(256, activation='relu'))
  model.add(layers.Dense(1, activation='sigmoid'))
  return model

# %%
#modify this 
norm_weight = 400/(2*(118+52))
tumor_weight = 400/(2*(161+69))

class_weights = {0:norm_weight, 1:tumor_weight}

# %%
import glob

#borrowed from svm code
def get_data_df(dir):
  # modified code from: https://www.kaggle.com/namgalielei/simple-load-images-and-count-number-of-each-class

  train_df = pd.DataFrame()

  trainset = glob.glob(dir)
  #print(trainset)
  train_df['filename'] = [img.split("/")[-4] + "/" + img.split("/")[-3] + "/" + img.split("/")[-2]+"/"+img.split("/")[-1] for img in trainset]
  train_df['label'] = [img.split("/")[-2] for img in trainset]

  return train_df

# %%
test_train = get_data_df(DATASET_01_TRAIN+"/*/*.jpg")
test_train.head()
# Out:
#                                    filename  label
# 0   mri-trainset/train/Tumor/Tumor (77).jpg  Tumor
# 1  mri-trainset/train/Tumor/Tumor (116).jpg  Tumor
# 2   mri-trainset/train/Tumor/Tumor (86).jpg  Tumor
# 3   mri-trainset/train/Tumor/Tumor (49).jpg  Tumor
# 4   mri-trainset/train/Tumor/Tumor (40).jpg  Tumor

# %%
from sklearn.model_selection import KFold, StratifiedKFold

train_data = get_data_df(DATASET_01_TRAIN+"/*/*.jpg")
Y = train_data[['label']]

#Y = final_train[['label']]
#n = len(final_train)   

skf = StratifiedKFold(n_splits = 5, random_state = 7, shuffle = True) 

#Un needed preprocessing aside from rescale
idg = ImageDataGenerator(rescale=1./255)

#model name
def get_model_name(k):
    return 'model_'+str(k)+'.h5'
def model_test(fold_count, epoch, model_method, image_size):
  skf = StratifiedKFold(n_splits = fold_count, random_state = 7, shuffle = True)
  train_data = get_data_df(DATASET_01_TRAIN+"/*/*.jpg")
  Y = train_data[['label']]
  n = len (train_data)
  #Incorperate preprocessing in the method 
  #####################################################################
  #aug_train = get_data_df(DATASET_01_ROOT+"/Aug_train/*/*.jpg")
  #aug_train['filename'] = aug_train['filename'].str[7:]
  #final_train = test_train.append(aug_train, sort=False, ignore_index=True)


  #######################################################################
  idg = ImageDataGenerator()
  #idg = ImageDataGenerator()
  #Y = final_train[['label']]
  #n = len(final_train)    
  VALIDATION_ACCURACY = []
  VALIDATION_LOSS = []

  #create a directory
  save_dir = KAGGLE_OUT+'/datasets/01_MRI/Saved_CNN_Models/Testing/'+model_method.__name__+'/AugTest'+'/'+str(epoch)+'epochs/'
  img_dir = ROOT_DIR

  fold_var = 1

  #n is number of samples, doesn't care about x values for split, just y
  for train_index, val_index in skf.split(np.zeros(n),Y):

    #Index value for fold
    training_data = train_data.iloc[train_index]
    validation_data = train_data.iloc[val_index]
    #generator for train
    #print("hi")
    #Modify the training size, have an input adjustability 
    train_data_generator = idg.flow_from_dataframe(training_data, directory = img_dir,
                      target_size=image_size, batch_size=32,
                    x_col = "filename", y_col = "label",
                    class_mode = "binary", shuffle = True)
    #print("hi")
    #generator for validation
    valid_data_generator  = idg.flow_from_dataframe(validation_data, directory = img_dir,
                target_size=image_size, batch_size=32,
                x_col = "filename", y_col = "label",
                class_mode = "binary", shuffle = True)
    #print("hi")
    #create a method for this
    # CREATE NEW MODEL
    model = model_method()
    # COMPILE NEW MODEL
    #Binary cross entropy, opt will be adam, metric will be binary accuracy?
    model.compile(loss=tf.keras.losses.BinaryCrossentropy(),
            optimizer= tf.keras.optimizers.Adam(learning_rate = 0.0001),
            metrics=['binary_accuracy'])
    
    # CREATE CALLBACKS
    #Unsure about checpoint
    checkpoint = tf.keras.callbacks.ModelCheckpoint(save_dir+model_method.__name__+"_"+get_model_name(fold_var), 
                monitor='val_binary_accuracy', verbose=1, 
                save_best_only=True, mode='max')
  
    callbacks_list = [checkpoint]
    # There can be other callbacks, but just showing one because it involves the model name
    # This saves the best model
    # FIT THE MODEL
    #Include the weights for classes
    history = model.fit(train_data_generator,
            epochs=epoch,
            callbacks=callbacks_list,
            validation_data=valid_data_generator)
  
    #PLOT HISTORY
    #Plots for whichever
    #		:
    #plt.plot(history.history['binary_accuracy'], label='accuracy')
    #plt.plot(history.history['val_binary_accuracy'], label = 'val_accuracy')
    #plt.xlabel('Epoch')
    #plt.ylabel('Accuracy')
    #plt.ylim([0.3, 1])
    #plt.legend(loc='lower right')
    #plt.show()
    #frame = {'Accuracy': history.history['binary_accuracy'], 'Val_Accuracy': history.history['val_binary_accuracy']}
    #fig = px.line(frame)
    #fig.show()
    fig = go.Figure()
    fig.add_trace(go.Scatter(y= history.history['binary_accuracy'],
                      mode='lines+markers',
                      name='Training Accuracy'))
    fig.add_trace(go.Scatter(y= history.history['val_binary_accuracy'],
                      mode='lines+markers',
                      name='Validation Accuracy'))
    fig.update_yaxes(range=[0.40, 1])
    fig.update_layout(
      title="Fold "+ str(fold_var)+ "'s performance",
      title_x=0.5,
      xaxis_title="Epochs",
      yaxis_title="Accuracy",
      autosize=False,
      width=800,
      height=400,
      margin=dict(l=20, r=20, t=40, b=20),)
    fig.show()
    #		:
    # LOAD BEST MODEL to evaluate the performance of the model
    model.load_weights(save_dir+model_method.__name__+"_" + "model_"+str(fold_var)+".h5")
    predictions = model.predict(test_set)
    predict_final = np.where(predictions >=0, 1,0)
    #predict_final = K.round(predictions)
    conf_mat = confusion_matrix(test_set.classes, predict_final)
    conf_mat_perc = conf_mat.astype('float') / conf_mat.sum(axis=1)[:, np.newaxis]
    class_acc = conf_mat_perc.diagonal()
    print(conf_mat)
    print()
    print(f"Normal accuracy: {class_acc[0]}")
    print(f"Tumor accuracy: {class_acc[1]}")
    print()
    target_names = ['Normal', 'Tumor']
    print(classification_report(test_set.classes, predict_final, target_names=target_names))
    print()
    w_acc = balanced_accuracy_score(test_set.classes, predict_final) 
    u_acc = accuracy_score(test_set.classes, predict_final)
    print(f'Unweighted Accuracy: {u_acc}')  
    print(f'Weighted Accuracy: {w_acc}')
    results = model.evaluate(test_set)
    
    results = dict(zip(model.metrics_names,results))
    
    VALIDATION_ACCURACY.append(results['binary_accuracy'])
    VALIDATION_LOSS.append(results['loss'])
    
    tf.keras.backend.clear_session()
    
    fold_var += 1

# %%
#model_test(5, 30, create_model_V1, (256,256))

# %%
#model_test(5, 30, create_model_V1_02, (256,256))

# %%
#model_test(5, 30, create_model_V1_04, (256,256))

# %%
#model_test(5, 30, create_model_V2, (256,256))

# %%
#model_test(5, 30, create_model_V2_02, (256,256))

# %%
#model_test(5, 30, create_model_V2_04, (256,256))

# %%
#model_test(5, 30, create_model_V3, (256,256))

# %%
#model_test(5, 30, create_model_V3_02, (256,256))

# %%
#model_test(5, 30, create_model_V3_04, (256,256))

# %%
#model_test(5, 30, create_model_V4, (256,256))

# %%
#model_test(5, 30, create_model_V4_02, (256,256))

# %%
#model_test(5, 30, create_model_V4_04, (256,256))

# %%
def transfer_learning_model_dense169_1():

  IMG_SHAPE = (256,256,3,)
 
  inputs = tf.keras.Input(shape=IMG_SHAPE)
  x = tf.keras.applications.densenet.preprocess_input(inputs)
  base_model = tf.keras.applications.densenet.DenseNet169(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
  #print(len(base_model.layers))
  base_model.trainable = True

  fine_tune_at = 500
  for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False

  x = base_model(x)
  global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
  x = global_average_layer(x)
  x = tf.keras.layers.Dropout(0.2)(x)
  prediction_layer = tf.keras.layers.Dense(1)
  outputs = prediction_layer(x)
  model = tf.keras.Model(inputs, outputs)
  #print(len(model.trainable_variables))
  return model

transfer_model_dense169 = transfer_learning_model_dense169_1()
# Out:
# 2022-05-10 01:49:18.044163: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-10 01:49:18.183580: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-10 01:49:18.184365: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-10 01:49:18.185694: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-10 01:49:18.186007: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-10 01:49:18.186931: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-10 01:49:18.188122: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-10 01:49:20.433278: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-10 01:49:20.434052: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-10 01:49:20.434727: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-10 01:49:20.436084: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51879936/51877672 [==============================] - 0s 0us/step
# 51888128/51877672 [==============================] - 0s 0us/step

# %%
model_test(5, 30, transfer_learning_model_dense169_1, (256,256))
# Out:
# Found 223 validated image filenames belonging to 2 classes.
# Found 56 validated image filenames belonging to 2 classes.
# 2022-05-10 01:49:30.790478: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/30
# 2022-05-10 01:49:40.586621: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 7/7 [==============================] - 22s 838ms/step - loss: 7.3987 - binary_accuracy: 0.4484 - val_loss: 8.4040 - val_binary_accuracy: 0.4286
#
# Epoch 00001: val_binary_accuracy improved from -inf to 0.42857, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 2/30
# 7/7 [==============================] - 1s 169ms/step - loss: 4.3801 - binary_accuracy: 0.6502 - val_loss: 7.8492 - val_binary_accuracy: 0.4464
#
# Epoch 00002: val_binary_accuracy improved from 0.42857 to 0.44643, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 3/30
# 7/7 [==============================] - 1s 160ms/step - loss: 3.0126 - binary_accuracy: 0.7489 - val_loss: 6.9998 - val_binary_accuracy: 0.4643
#
# Epoch 00003: val_binary_accuracy improved from 0.44643 to 0.46429, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 4/30
# 7/7 [==============================] - 1s 160ms/step - loss: 2.2087 - binary_accuracy: 0.8027 - val_loss: 5.9747 - val_binary_accuracy: 0.5357
#
# Epoch 00004: val_binary_accuracy improved from 0.46429 to 0.53571, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 5/30
# 7/7 [==============================] - 1s 158ms/step - loss: 1.5727 - binary_accuracy: 0.8789 - val_loss: 5.6023 - val_binary_accuracy: 0.5893
#
# Epoch 00005: val_binary_accuracy improved from 0.53571 to 0.58929, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 6/30
# 7/7 [==============================] - 1s 157ms/step - loss: 1.2129 - binary_accuracy: 0.9103 - val_loss: 4.5825 - val_binary_accuracy: 0.5893
#
# Epoch 00006: val_binary_accuracy did not improve from 0.58929
# Epoch 7/30
# 7/7 [==============================] - 1s 159ms/step - loss: 1.4325 - binary_accuracy: 0.8879 - val_loss: 4.6982 - val_binary_accuracy: 0.6071
#
# Epoch 00007: val_binary_accuracy improved from 0.58929 to 0.60714, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 8/30
# 7/7 [==============================] - 1s 207ms/step - loss: 0.6667 - binary_accuracy: 0.9327 - val_loss: 5.3329 - val_binary_accuracy: 0.6250
#
# Epoch 00008: val_binary_accuracy improved from 0.60714 to 0.62500, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 9/30
# 7/7 [==============================] - 1s 157ms/step - loss: 0.6705 - binary_accuracy: 0.9417 - val_loss: 5.0853 - val_binary_accuracy: 0.6429
#
# Epoch 00009: val_binary_accuracy improved from 0.62500 to 0.64286, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 10/30
# 7/7 [==============================] - 1s 154ms/step - loss: 0.5253 - binary_accuracy: 0.9462 - val_loss: 3.8073 - val_binary_accuracy: 0.6429
#
# Epoch 00010: val_binary_accuracy did not improve from 0.64286
# Epoch 11/30
# 7/7 [==============================] - 1s 145ms/step - loss: 0.2912 - binary_accuracy: 0.9776 - val_loss: 3.4497 - val_binary_accuracy: 0.6786
#
# Epoch 00011: val_binary_accuracy improved from 0.64286 to 0.67857, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 12/30
# 7/7 [==============================] - 1s 154ms/step - loss: 0.2354 - binary_accuracy: 0.9686 - val_loss: 3.3861 - val_binary_accuracy: 0.7500
#
# Epoch 00012: val_binary_accuracy improved from 0.67857 to 0.75000, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 13/30
# 7/7 [==============================] - 1s 170ms/step - loss: 0.2142 - binary_accuracy: 0.9865 - val_loss: 1.9848 - val_binary_accuracy: 0.7857
#
# Epoch 00013: val_binary_accuracy improved from 0.75000 to 0.78571, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 14/30
# 7/7 [==============================] - 1s 150ms/step - loss: 0.1605 - binary_accuracy: 0.9731 - val_loss: 1.8048 - val_binary_accuracy: 0.7857
#
# Epoch 00014: val_binary_accuracy did not improve from 0.78571
# Epoch 15/30
# 7/7 [==============================] - 1s 158ms/step - loss: 0.1552 - binary_accuracy: 0.9821 - val_loss: 1.5303 - val_binary_accuracy: 0.8393
#
# Epoch 00015: val_binary_accuracy improved from 0.78571 to 0.83929, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 16/30
# 7/7 [==============================] - 1s 156ms/step - loss: 0.1794 - binary_accuracy: 0.9776 - val_loss: 1.2203 - val_binary_accuracy: 0.8750
#
# Epoch 00016: val_binary_accuracy improved from 0.83929 to 0.87500, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 17/30
# 7/7 [==============================] - 1s 161ms/step - loss: 0.0854 - binary_accuracy: 0.9865 - val_loss: 1.0522 - val_binary_accuracy: 0.8929
#
# Epoch 00017: val_binary_accuracy improved from 0.87500 to 0.89286, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 18/30
# 7/7 [==============================] - 1s 191ms/step - loss: 0.2921 - binary_accuracy: 0.9731 - val_loss: 0.6858 - val_binary_accuracy: 0.8929
#
# Epoch 00018: val_binary_accuracy did not improve from 0.89286
# Epoch 19/30
# 7/7 [==============================] - 1s 162ms/step - loss: 0.0725 - binary_accuracy: 0.9955 - val_loss: 0.4044 - val_binary_accuracy: 0.9107
#
# Epoch 00019: val_binary_accuracy improved from 0.89286 to 0.91071, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 20/30
# 7/7 [==============================] - 1s 151ms/step - loss: 0.0864 - binary_accuracy: 0.9865 - val_loss: 0.3640 - val_binary_accuracy: 0.9286
#
# Epoch 00020: val_binary_accuracy improved from 0.91071 to 0.92857, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 21/30
# 7/7 [==============================] - 1s 165ms/step - loss: 0.0777 - binary_accuracy: 0.9910 - val_loss: 0.3493 - val_binary_accuracy: 0.9286
#
# Epoch 00021: val_binary_accuracy did not improve from 0.92857
# Epoch 22/30
# 7/7 [==============================] - 1s 165ms/step - loss: 0.0759 - binary_accuracy: 0.9910 - val_loss: 0.3405 - val_binary_accuracy: 0.9286
#
# Epoch 00022: val_binary_accuracy did not improve from 0.92857
# Epoch 23/30
# 7/7 [==============================] - 1s 150ms/step - loss: 0.0751 - binary_accuracy: 0.9910 - val_loss: 0.1089 - val_binary_accuracy: 0.9286
#
# Epoch 00023: val_binary_accuracy did not improve from 0.92857
# Epoch 24/30
# 7/7 [==============================] - 1s 158ms/step - loss: 0.0692 - binary_accuracy: 0.9955 - val_loss: 0.0897 - val_binary_accuracy: 0.9286
#
# Epoch 00024: val_binary_accuracy did not improve from 0.92857
# Epoch 25/30
# 7/7 [==============================] - 1s 160ms/step - loss: 0.0956 - binary_accuracy: 0.9910 - val_loss: 0.0842 - val_binary_accuracy: 0.9643
#
# Epoch 00025: val_binary_accuracy improved from 0.92857 to 0.96429, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_1.h5
# Epoch 26/30
# 7/7 [==============================] - 2s 231ms/step - loss: 0.1420 - binary_accuracy: 0.9865 - val_loss: 0.3283 - val_binary_accuracy: 0.9464
#
# Epoch 00026: val_binary_accuracy did not improve from 0.96429
# Epoch 27/30
# 7/7 [==============================] - 1s 162ms/step - loss: 0.2354 - binary_accuracy: 0.9686 - val_loss: 0.3378 - val_binary_accuracy: 0.9643
#
# Epoch 00027: val_binary_accuracy did not improve from 0.96429
# Epoch 28/30
# 7/7 [==============================] - 1s 162ms/step - loss: 0.2235 - binary_accuracy: 0.9821 - val_loss: 0.3357 - val_binary_accuracy: 0.9643
#
# Epoch 00028: val_binary_accuracy did not improve from 0.96429
# Epoch 29/30
# 7/7 [==============================] - 1s 161ms/step - loss: 0.0841 - binary_accuracy: 0.9865 - val_loss: 0.3362 - val_binary_accuracy: 0.9464
#
# Epoch 00029: val_binary_accuracy did not improve from 0.96429
# Epoch 30/30
# 7/7 [==============================] - 1s 152ms/step - loss: 0.1557 - binary_accuracy: 0.9821 - val_loss: 0.3333 - val_binary_accuracy: 0.9464
#
# Epoch 00030: val_binary_accuracy did not improve from 0.96429
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="3a5c9bae-66d7-47aa-a5d4-66a93042aa81" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a5c9bae-66d7-47aa-a5d4-66a93042aa81")) {                    Plotly.newPlot(                        "3a5c9bae-66d7-47aa-a5d4-66a93042aa81",                        [{"mode":"lines+markers","name":"Training Accuracy","y":[0.44843047857284546,0.6502242088317871,0.7488788962364197,0.8026905655860901,0.878923773765564,0.9103139042854309,0.8878923654556274,0.9327354431152344,0.9417040348052979,0.9461883306503296,0.9775784611701965,0.9686098694801331,0.9865471124649048,0.9730941653251648,0.9820627570152283,0.9775784611701965,0.9865471124649048,0.9730941653251648,0.9955157041549683,0.9865471124649048,0.9910314083099365,0.9910314083099365,0.9910314083099365,0.9955157041549683,0.9910314083099365,0.9865471124649048,0.9686098694801331,0.9820627570152283,0.9865471124649048,0.9820627570152283],"type":"scatter"},{"mode":"lines+markers","name":"Validation Accuracy","y":[0.4285714328289032,0.4464285671710968,0.4642857015132904,0.5357142686843872,0.5892857313156128,0.5892857313156128,0.6071428656578064,0.625,0.6428571343421936,0.6428571343421936,0.6785714030265808,0.75,0.7857142686843872,0.7857142686843872,0.8392857313156128,0.875,0.8928571343421936,0.8928571343421936,0.9107142686843872,0.9285714030265808,0.9285714030265808,0.9285714030265808,0.9285714030265808,0.9285714030265808,0.9642857313156128,0.9464285969734192,0.9642857313156128,0.9642857313156128,0.9464285969734192,0.9464285969734192],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222 ...
# [[47  5]
#  [ 2 67]]
#
# Normal accuracy: 0.9038461538461539
# Tumor accuracy: 0.9710144927536232
#
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.90      0.93        52
#        Tumor       0.93      0.97      0.95        69
#
#     accuracy                           0.94       121
#    macro avg       0.94      0.94      0.94       121
# weighted avg       0.94      0.94      0.94       121
#
#
# Unweighted Accuracy: 0.9421487603305785
# Weighted Accuracy: 0.9374303232998885
# 4/4 [==============================] - 1s 98ms/step - loss: 0.5470 - binary_accuracy: 0.9504
# Found 223 validated image filenames belonging to 2 classes.
# Found 56 validated image filenames belonging to 2 classes.
# Epoch 1/30
# 7/7 [==============================] - 12s 545ms/step - loss: 3.4901 - binary_accuracy: 0.5695 - val_loss: 3.3244 - val_binary_accuracy: 0.6607
#
# Epoch 00001: val_binary_accuracy improved from -inf to 0.66071, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_2.h5
# Epoch 2/30
# 7/7 [==============================] - 1s 156ms/step - loss: 1.6897 - binary_accuracy: 0.8341 - val_loss: 2.4027 - val_binary_accuracy: 0.7500
#
# Epoch 00002: val_binary_accuracy improved from 0.66071 to 0.75000, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_2.h5
# Epoch 3/30
# 7/7 [==============================] - 1s 197ms/step - loss: 1.1361 - binary_accuracy: 0.8879 - val_loss: 1.5897 - val_binary_accuracy: 0.8036
#
# Epoch 00003: val_binary_accuracy improved from 0.75000 to 0.80357, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_2.h5
# Epoch 4/30
# 7/7 [==============================] - 1s 156ms/step - loss: 0.7319 - binary_accuracy: 0.9148 - val_loss: 1.1020 - val_binary_accuracy: 0.8214
#
# Epoch 00004: val_binary_accuracy improved from 0.80357 to 0.82143, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_2.h5
# Epoch 5/30
# 7/7 [==============================] - 1s 156ms/step - loss: 0.5022 - binary_accuracy: 0.9238 - val_loss: 1.2535 - val_binary_accuracy: 0.8571
#
# Epoch 00005: val_binary_accuracy improved from 0.82143 to 0.85714, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_2.h5
# Epoch 6/30
# 7/7 [==============================] - 1s 156ms/step - loss: 0.5265 - binary_accuracy: 0.9507 - val_loss: 1.2046 - val_binary_accuracy: 0.8750
#
# Epoch 00006: val_binary_accuracy improved from 0.85714 to 0.87500, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_2.h5
# Epoch 7/30
# 7/7 [==============================] - 1s 160ms/step - loss: 0.3243 - binary_accuracy: 0.9507 - val_loss: 0.9816 - val_binary_accuracy: 0.9107
#
# Epoch 00007: val_binary_accuracy improved from 0.87500 to 0.91071, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_2.h5
# Epoch 8/30
# 7/7 [==============================] - 1s 197ms/step - loss: 0.1649 - binary_accuracy: 0.9731 - val_loss: 0.9515 - val_binary_accuracy: 0.8929
#
# Epoch 00008: val_binary_accuracy did not improve from 0.91071
# Epoch 9/30
# 7/7 [==============================] - 1s 153ms/step - loss: 0.2259 - binary_accuracy: 0.9776 - val_loss: 0.9355 - val_binary_accuracy: 0.8929
#
# Epoch 00009: val_binary_accuracy did not improve from 0.91071
# Epoch 10/30
# 7/7 [==============================] - 1s 160ms/step - loss: 0.1500 - binary_accuracy: 0.9821 - val_loss: 0.9256 - val_binary_accuracy: 0.8929
#
# Epoch 00010: val_binary_accuracy did not improve from 0.91071
# Epoch 11/30
# 7/7 [==============================] - 1s 152ms/step - loss: 0.1480 - binary_accuracy: 0.9865 - val_loss: 0.9189 - val_binary_accuracy: 0.8929
#
# Epoch 00011: val_binary_accuracy did not improve from 0.91071
# Epoch 12/30
# 7/7 [==============================] - 1s 164ms/step - loss: 0.2273 - binary_accuracy: 0.9821 - val_loss: 0.6883 - val_binary_accuracy: 0.8929
#
# Epoch 00012: val_binary_accuracy did not improve from 0.91071
# Epoch 13/30
# 7/7 [==============================] - 1s 158ms/step - loss: 0.1464 - binary_accuracy: 0.9865 - val_loss: 0.4532 - val_binary_accuracy: 0.8929
#
# Epoch 00013: val_binary_accuracy did not improve from 0.91071
# Epoch 14/30
# 7/7 [==============================] - 1s 154ms/step - loss: 0.1482 - binary_accuracy: 0.9910 - val_loss: 0.4417 - val_binary_accuracy: 0.8929
#
# Epoch 00014: val_binary_accuracy did not improve from 0.91071
# Epoch 15/30
# 7/7 [==============================] - 1s 157ms/step - loss: 0.1521 - binary_accuracy: 0.9821 - val_loss: 0.6385 - val_binary_accuracy: 0.9107
#
# Epoch 00015: val_binary_accuracy did not improve from 0.91071
# Epoch 16/30
# 7/7 [==============================] - 1s 166ms/step - loss: 0.1431 - binary_accuracy: 0.9865 - val_loss: 0.6277 - val_binary_accuracy: 0.9107
#
# Epoch 00016: val_binary_accuracy did not improve from 0.91071
# Epoch 17/30
# 7/7 [==============================] - 1s 195ms/step - loss: 0.2455 - binary_accuracy: 0.9731 - val_loss: 0.4158 - val_binary_accuracy: 0.9107
#
# Epoch 00017: val_binary_accuracy did not improve from 0.91071
# Epoch 18/30
# 7/7 [==============================] - 1s 166ms/step - loss: 0.1381 - binary_accuracy: 0.9910 - val_loss: 0.4132 - val_binary_accuracy: 0.9286
#
# Epoch 00018: val_binary_accuracy improved from 0.91071 to 0.92857, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_2.h5
# Epoch 19/30
# 7/7 [==============================] - 1s 154ms/step - loss: 0.1378 - binary_accuracy: 0.9910 - val_loss: 0.4267 - val_binary_accuracy: 0.9286
#
# Epoch 00019: val_binary_accuracy did not improve from 0.92857
# Epoch 20/30
# 7/7 [==============================] - 1s 156ms/step - loss: 0.1416 - binary_accuracy: 0.9910 - val_loss: 0.6117 - val_binary_accuracy: 0.9286
#
# Epoch 00020: val_binary_accuracy did not improve from 0.92857
# Epoch 21/30
# 7/7 [==============================] - 1s 162ms/step - loss: 0.1474 - binary_accuracy: 0.9865 - val_loss: 0.6041 - val_binary_accuracy: 0.9286
#
# Epoch 00021: val_binary_accuracy did not improve from 0.92857
# Epoch 22/30
# 7/7 [==============================] - 1s 163ms/step - loss: 0.1373 - binary_accuracy: 0.9910 - val_loss: 0.5950 - val_binary_accuracy: 0.9464
#
# Epoch 00022: val_binary_accuracy improved from 0.92857 to 0.94643, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_2.h5
# Epoch 23/30
# 7/7 [==============================] - 1s 164ms/step - loss: 0.1405 - binary_accuracy: 0.9910 - val_loss: 0.5896 - val_binary_accuracy: 0.9464
#
# Epoch 00023: val_binary_accuracy did not improve from 0.94643
# Epoch 24/30
# 7/7 [==============================] - 1s 161ms/step - loss: 0.1393 - binary_accuracy: 0.9910 - val_loss: 0.5876 - val_binary_accuracy: 0.9464
#
# Epoch 00024: val_binary_accuracy did not improve from 0.94643
# Epoch 25/30
# 7/7 [==============================] - 2s 242ms/step - loss: 0.0733 - binary_accuracy: 0.9910 - val_loss: 0.5841 - val_binary_accuracy: 0.9464
#
# Epoch 00025: val_binary_accuracy did not improve from 0.94643
# Epoch 26/30
# 7/7 [==============================] - 1s 159ms/step - loss: 0.1395 - binary_accuracy: 0.9910 - val_loss: 0.5818 - val_binary_accuracy: 0.9464
#
# Epoch 00026: val_binary_accuracy did not improve from 0.94643
# Epoch 27/30
# 7/7 [==============================] - 1s 161ms/step - loss: 0.0772 - binary_accuracy: 0.9910 - val_loss: 0.5790 - val_binary_accuracy: 0.9464
#
# Epoch 00027: val_binary_accuracy did not improve from 0.94643
# Epoch 28/30
# 7/7 [==============================] - 1s 159ms/step - loss: 0.0782 - binary_accuracy: 0.9865 - val_loss: 0.5766 - val_binary_accuracy: 0.9464
#
# Epoch 00028: val_binary_accuracy did not improve from 0.94643
# Epoch 29/30
# 7/7 [==============================] - 1s 153ms/step - loss: 0.0767 - binary_accuracy: 0.9910 - val_loss: 0.5705 - val_binary_accuracy: 0.9464
#
# Epoch 00029: val_binary_accuracy did not improve from 0.94643
# Epoch 30/30
# 7/7 [==============================] - 1s 157ms/step - loss: 0.0868 - binary_accuracy: 0.9865 - val_loss: 0.5721 - val_binary_accuracy: 0.9464
#
# Epoch 00030: val_binary_accuracy did not improve from 0.94643
# <div>                            <div id="ebee2676-bbb4-45bd-a29b-cc3449deb81f" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ebee2676-bbb4-45bd-a29b-cc3449deb81f")) {                    Plotly.newPlot(                        "ebee2676-bbb4-45bd-a29b-cc3449deb81f",                        [{"mode":"lines+markers","name":"Training Accuracy","y":[0.5695067048072815,0.834080696105957,0.8878923654556274,0.9147982001304626,0.9237667918205261,0.9506726264953613,0.9506726264953613,0.9730941653251648,0.9775784611701965,0.9820627570152283,0.9865471124649048,0.9820627570152283,0.9865471124649048,0.9910314083099365,0.9820627570152283,0.9865471124649048,0.9730941653251648,0.9910314083099365,0.9910314083099365,0.9910314083099365,0.9865471124649048,0.9910314083099365,0.9910314083099365,0.9910314083099365,0.9910314083099365,0.9910314083099365,0.9910314083099365,0.9865471124649048,0.9910314083099365,0.9865471124649048],"type":"scatter"},{"mode":"lines+markers","name":"Validation Accuracy","y":[0.6607142686843872,0.75,0.8035714030265808,0.8214285969734192,0.8571428656578064,0.875,0.9107142686843872,0.8928571343421936,0.8928571343421936,0.8928571343421936,0.8928571343421936,0.8928571343421936,0.8928571343421936,0.8928571343421936,0.9107142686843872,0.9107142686843872,0.9107142686843872,0.9285714030265808,0.9285714030265808,0.9285714030265808,0.9285714030265808,0.9464285969734192,0.9464285969734192,0.9464285969734192,0.9464285969734192,0.9464285969734192,0.9464285969734192,0.9464285969734192,0.9464285969734192,0.9464285969734192],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039 ...
# [[50  2]
#  [ 1 68]]
#
# Normal accuracy: 0.9615384615384616
# Tumor accuracy: 0.9855072463768116
#
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.96      0.97        52
#        Tumor       0.97      0.99      0.98        69
#
#     accuracy                           0.98       121
#    macro avg       0.98      0.97      0.97       121
# weighted avg       0.98      0.98      0.98       121
#
#
# Unweighted Accuracy: 0.9752066115702479
# Weighted Accuracy: 0.9735228539576366
# 4/4 [==============================] - 1s 102ms/step - loss: 0.2919 - binary_accuracy: 0.9587
# Found 223 validated image filenames belonging to 2 classes.
# Found 56 validated image filenames belonging to 2 classes.
# Epoch 1/30
# 7/7 [==============================] - 12s 558ms/step - loss: 6.2519 - binary_accuracy: 0.4933 - val_loss: 7.5514 - val_binary_accuracy: 0.4643
#
# Epoch 00001: val_binary_accuracy improved from -inf to 0.46429, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_3.h5
# Epoch 2/30
# 7/7 [==============================] - 1s 153ms/step - loss: 4.1106 - binary_accuracy: 0.6368 - val_loss: 8.2794 - val_binary_accuracy: 0.4464
#
# Epoch 00002: val_binary_accuracy did not improve from 0.46429
# Epoch 3/30
# 7/7 [==============================] - 1s 157ms/step - loss: 3.6037 - binary_accuracy: 0.7085 - val_loss: 8.2804 - val_binary_accuracy: 0.4464
#
# Epoch 00003: val_binary_accuracy did not improve from 0.46429
# Epoch 4/30
# 7/7 [==============================] - 2s 264ms/step - loss: 3.0240 - binary_accuracy: 0.7578 - val_loss: 7.5768 - val_binary_accuracy: 0.4643
#
# Epoch 00004: val_binary_accuracy did not improve from 0.46429
# Epoch 5/30
# 7/7 [==============================] - 1s 161ms/step - loss: 2.8340 - binary_accuracy: 0.7534 - val_loss: 7.3003 - val_binary_accuracy: 0.4643
#
# Epoch 00005: val_binary_accuracy did not improve from 0.46429
# Epoch 6/30
# 7/7 [==============================] - 1s 158ms/step - loss: 2.1786 - binary_accuracy: 0.8206 - val_loss: 6.5656 - val_binary_accuracy: 0.4821
#
# Epoch 00006: val_binary_accuracy improved from 0.46429 to 0.48214, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_3.h5
# Epoch 7/30
# 7/7 [==============================] - 1s 152ms/step - loss: 1.8166 - binary_accuracy: 0.8430 - val_loss: 6.0337 - val_binary_accuracy: 0.5179
#
# Epoch 00007: val_binary_accuracy improved from 0.48214 to 0.51786, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_3.h5
# Epoch 8/30
# 7/7 [==============================] - 1s 155ms/step - loss: 1.6168 - binary_accuracy: 0.8565 - val_loss: 5.4494 - val_binary_accuracy: 0.5536
#
# Epoch 00008: val_binary_accuracy improved from 0.51786 to 0.55357, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_3.h5
# Epoch 9/30
# 7/7 [==============================] - 1s 159ms/step - loss: 1.2957 - binary_accuracy: 0.8610 - val_loss: 4.8605 - val_binary_accuracy: 0.6250
#
# Epoch 00009: val_binary_accuracy improved from 0.55357 to 0.62500, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_3.h5
# Epoch 10/30
# 7/7 [==============================] - 1s 159ms/step - loss: 0.8713 - binary_accuracy: 0.9327 - val_loss: 4.2662 - val_binary_accuracy: 0.6250
#
# Epoch 00010: val_binary_accuracy did not improve from 0.62500
# Epoch 11/30
# 7/7 [==============================] - 1s 166ms/step - loss: 0.7807 - binary_accuracy: 0.9462 - val_loss: 3.7215 - val_binary_accuracy: 0.6786
#
# Epoch 00011: val_binary_accuracy improved from 0.62500 to 0.67857, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_3.h5
# Epoch 12/30
# 7/7 [==============================] - 1s 154ms/step - loss: 0.4995 - binary_accuracy: 0.9641 - val_loss: 3.4515 - val_binary_accuracy: 0.7143
#
# Epoch 00012: val_binary_accuracy improved from 0.67857 to 0.71429, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_3.h5
# Epoch 13/30
# 7/7 [==============================] - 1s 160ms/step - loss: 0.6494 - binary_accuracy: 0.9507 - val_loss: 2.4168 - val_binary_accuracy: 0.7321
#
# Epoch 00013: val_binary_accuracy improved from 0.71429 to 0.73214, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_3.h5
# Epoch 14/30
# 7/7 [==============================] - 1s 158ms/step - loss: 0.3734 - binary_accuracy: 0.9596 - val_loss: 2.3336 - val_binary_accuracy: 0.7679
#
# Epoch 00014: val_binary_accuracy improved from 0.73214 to 0.76786, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_3.h5
# Epoch 15/30
# 7/7 [==============================] - 1s 198ms/step - loss: 0.3641 - binary_accuracy: 0.9686 - val_loss: 2.0522 - val_binary_accuracy: 0.7857
#
# Epoch 00015: val_binary_accuracy improved from 0.76786 to 0.78571, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_3.h5
# Epoch 16/30
# 7/7 [==============================] - 1s 157ms/step - loss: 0.4229 - binary_accuracy: 0.9731 - val_loss: 1.7756 - val_binary_accuracy: 0.8393
#
# Epoch 00016: val_binary_accuracy improved from 0.78571 to 0.83929, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_3.h5
# Epoch 17/30
# 7/7 [==============================] - 1s 159ms/step - loss: 0.3144 - binary_accuracy: 0.9686 - val_loss: 1.7936 - val_binary_accuracy: 0.8393
#
# Epoch 00017: val_binary_accuracy did not improve from 0.83929
# Epoch 18/30
# 7/7 [==============================] - 1s 157ms/step - loss: 0.2286 - binary_accuracy: 0.9776 - val_loss: 1.8111 - val_binary_accuracy: 0.8036
#
# Epoch 00018: val_binary_accuracy did not improve from 0.83929
# Epoch 19/30
# 7/7 [==============================] - 1s 156ms/step - loss: 0.2788 - binary_accuracy: 0.9821 - val_loss: 1.7866 - val_binary_accuracy: 0.8036
#
# Epoch 00019: val_binary_accuracy did not improve from 0.83929
# Epoch 20/30
# 7/7 [==============================] - 1s 158ms/step - loss: 0.3190 - binary_accuracy: 0.9641 - val_loss: 1.7434 - val_binary_accuracy: 0.8571
#
# Epoch 00020: val_binary_accuracy improved from 0.83929 to 0.85714, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_3.h5
# Epoch 21/30
# 7/7 [==============================] - 1s 196ms/step - loss: 0.2795 - binary_accuracy: 0.9821 - val_loss: 1.7242 - val_binary_accuracy: 0.8571
#
# Epoch 00021: val_binary_accuracy did not improve from 0.85714
# Epoch 22/30
# 7/7 [==============================] - 1s 159ms/step - loss: 0.3625 - binary_accuracy: 0.9641 - val_loss: 1.7057 - val_binary_accuracy: 0.8571
#
# Epoch 00022: val_binary_accuracy did not improve from 0.85714
# Epoch 23/30
# 7/7 [==============================] - 1s 153ms/step - loss: 0.2290 - binary_accuracy: 0.9821 - val_loss: 1.4632 - val_binary_accuracy: 0.8750
#
# Epoch 00023: val_binary_accuracy improved from 0.85714 to 0.87500, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_3.h5
# Epoch 24/30
# 7/7 [==============================] - 1s 159ms/step - loss: 0.2096 - binary_accuracy: 0.9865 - val_loss: 1.4352 - val_binary_accuracy: 0.8929
#
# Epoch 00024: val_binary_accuracy improved from 0.87500 to 0.89286, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_3.h5
# Epoch 25/30
# 7/7 [==============================] - 1s 151ms/step - loss: 0.2843 - binary_accuracy: 0.9776 - val_loss: 1.4182 - val_binary_accuracy: 0.8929
#
# Epoch 00025: val_binary_accuracy did not improve from 0.89286
# Epoch 26/30
# 7/7 [==============================] - 1s 153ms/step - loss: 0.1499 - binary_accuracy: 0.9821 - val_loss: 1.4061 - val_binary_accuracy: 0.8929
#
# Epoch 00026: val_binary_accuracy did not improve from 0.89286
# Epoch 27/30
# 7/7 [==============================] - 1s 173ms/step - loss: 0.1521 - binary_accuracy: 0.9865 - val_loss: 1.3950 - val_binary_accuracy: 0.8929
#
# Epoch 00027: val_binary_accuracy did not improve from 0.89286
# Epoch 28/30
# 7/7 [==============================] - 2s 226ms/step - loss: 0.1578 - binary_accuracy: 0.9776 - val_loss: 1.3945 - val_binary_accuracy: 0.9107
#
# Epoch 00028: val_binary_accuracy improved from 0.89286 to 0.91071, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_3.h5
# Epoch 29/30
# 7/7 [==============================] - 1s 161ms/step - loss: 0.0735 - binary_accuracy: 0.9910 - val_loss: 1.2311 - val_binary_accuracy: 0.8929
#
# Epoch 00029: val_binary_accuracy did not improve from 0.91071
# Epoch 30/30
# 7/7 [==============================] - 1s 158ms/step - loss: 0.1433 - binary_accuracy: 0.9910 - val_loss: 1.1685 - val_binary_accuracy: 0.8929
#
# Epoch 00030: val_binary_accuracy did not improve from 0.91071
# <div>                            <div id="4e32a716-de84-4c19-ac2b-b62fe5210c05" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e32a716-de84-4c19-ac2b-b62fe5210c05")) {                    Plotly.newPlot(                        "4e32a716-de84-4c19-ac2b-b62fe5210c05",                        [{"mode":"lines+markers","name":"Training Accuracy","y":[0.4932735562324524,0.6367713212966919,0.7085201740264893,0.7578475475311279,0.7533632516860962,0.8206278085708618,0.8430493474006653,0.8565022349357605,0.8609865307807922,0.9327354431152344,0.9461883306503296,0.9641255736351013,0.9506726264953613,0.9596412777900696,0.9686098694801331,0.9730941653251648,0.9686098694801331,0.9775784611701965,0.9820627570152283,0.9641255736351013,0.9820627570152283,0.9641255736351013,0.9820627570152283,0.9865471124649048,0.9775784611701965,0.9820627570152283,0.9865471124649048,0.9775784611701965,0.9910314083099365,0.9910314083099365],"type":"scatter"},{"mode":"lines+markers","name":"Validation Accuracy","y":[0.4642857015132904,0.4464285671710968,0.4464285671710968,0.4642857015132904,0.4642857015132904,0.4821428656578064,0.5178571343421936,0.5535714030265808,0.625,0.625,0.6785714030265808,0.7142857313156128,0.7321428656578064,0.7678571343421936,0.7857142686843872,0.8392857313156128,0.8392857313156128,0.8035714030265808,0.8035714030265808,0.8571428656578064,0.8571428656578064,0.8571428656578064,0.875,0.8928571343421936,0.8928571343421936,0.8928571343421936,0.8928571343421936,0.9107142686843872,0.8928571343421936,0.8928571343421936],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222 ...
# [[47  5]
#  [ 2 67]]
#
# Normal accuracy: 0.9038461538461539
# Tumor accuracy: 0.9710144927536232
#
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.90      0.93        52
#        Tumor       0.93      0.97      0.95        69
#
#     accuracy                           0.94       121
#    macro avg       0.94      0.94      0.94       121
# weighted avg       0.94      0.94      0.94       121
#
#
# Unweighted Accuracy: 0.9421487603305785
# Weighted Accuracy: 0.9374303232998885
# 4/4 [==============================] - 1s 99ms/step - loss: 0.4751 - binary_accuracy: 0.9174
# Found 223 validated image filenames belonging to 2 classes.
# Found 56 validated image filenames belonging to 2 classes.
# Epoch 1/30
# 7/7 [==============================] - 13s 562ms/step - loss: 2.9103 - binary_accuracy: 0.6457 - val_loss: 2.9787 - val_binary_accuracy: 0.5357
#
# Epoch 00001: val_binary_accuracy improved from -inf to 0.53571, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_4.h5
# Epoch 2/30
# 7/7 [==============================] - 1s 158ms/step - loss: 1.4007 - binary_accuracy: 0.8117 - val_loss: 1.7897 - val_binary_accuracy: 0.6786
#
# Epoch 00002: val_binary_accuracy improved from 0.53571 to 0.67857, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_4.h5
# Epoch 3/30
# 7/7 [==============================] - 1s 159ms/step - loss: 0.8872 - binary_accuracy: 0.8700 - val_loss: 1.3872 - val_binary_accuracy: 0.7679
#
# Epoch 00003: val_binary_accuracy improved from 0.67857 to 0.76786, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_4.h5
# Epoch 4/30
# 7/7 [==============================] - 1s 157ms/step - loss: 0.6806 - binary_accuracy: 0.9238 - val_loss: 1.2692 - val_binary_accuracy: 0.8036
#
# Epoch 00004: val_binary_accuracy improved from 0.76786 to 0.80357, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_4.h5
# Epoch 5/30
# 7/7 [==============================] - 1s 164ms/step - loss: 0.5843 - binary_accuracy: 0.9148 - val_loss: 1.2163 - val_binary_accuracy: 0.8571
#
# Epoch 00005: val_binary_accuracy improved from 0.80357 to 0.85714, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_4.h5
# Epoch 6/30
# 7/7 [==============================] - 1s 164ms/step - loss: 0.4379 - binary_accuracy: 0.9641 - val_loss: 1.0167 - val_binary_accuracy: 0.8571
#
# Epoch 00006: val_binary_accuracy did not improve from 0.85714
# Epoch 7/30
# 7/7 [==============================] - 1s 166ms/step - loss: 0.3041 - binary_accuracy: 0.9686 - val_loss: 0.7168 - val_binary_accuracy: 0.8571
#
# Epoch 00007: val_binary_accuracy did not improve from 0.85714
# Epoch 8/30
# 7/7 [==============================] - 1s 167ms/step - loss: 0.2569 - binary_accuracy: 0.9596 - val_loss: 0.6725 - val_binary_accuracy: 0.8571
#
# Epoch 00008: val_binary_accuracy did not improve from 0.85714
# Epoch 9/30
# 7/7 [==============================] - 1s 165ms/step - loss: 0.0517 - binary_accuracy: 0.9821 - val_loss: 0.4040 - val_binary_accuracy: 0.8929
#
# Epoch 00009: val_binary_accuracy improved from 0.85714 to 0.89286, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_4.h5
# Epoch 10/30
# 7/7 [==============================] - 1s 158ms/step - loss: 0.0102 - binary_accuracy: 0.9955 - val_loss: 0.3801 - val_binary_accuracy: 0.9286
#
# Epoch 00010: val_binary_accuracy improved from 0.89286 to 0.92857, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_4.h5
# Epoch 11/30
# 7/7 [==============================] - 1s 198ms/step - loss: 0.0112 - binary_accuracy: 0.9955 - val_loss: 0.3708 - val_binary_accuracy: 0.9286
#
# Epoch 00011: val_binary_accuracy did not improve from 0.92857
# Epoch 12/30
# 7/7 [==============================] - 1s 162ms/step - loss: 0.0166 - binary_accuracy: 0.9955 - val_loss: 0.1541 - val_binary_accuracy: 0.9286
#
# Epoch 00012: val_binary_accuracy did not improve from 0.92857
# Epoch 13/30
# 7/7 [==============================] - 1s 158ms/step - loss: 0.0089 - binary_accuracy: 0.9910 - val_loss: 0.1357 - val_binary_accuracy: 0.9286
#
# Epoch 00013: val_binary_accuracy did not improve from 0.92857
# Epoch 14/30
# 7/7 [==============================] - 1s 154ms/step - loss: 0.0049 - binary_accuracy: 1.0000 - val_loss: 0.1206 - val_binary_accuracy: 0.9464
#
# Epoch 00014: val_binary_accuracy improved from 0.92857 to 0.94643, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_4.h5
# Epoch 15/30
# 7/7 [==============================] - 1s 153ms/step - loss: 0.0115 - binary_accuracy: 0.9955 - val_loss: 0.1107 - val_binary_accuracy: 0.9464
#
# Epoch 00015: val_binary_accuracy did not improve from 0.94643
# Epoch 16/30
# 7/7 [==============================] - 1s 159ms/step - loss: 0.0024 - binary_accuracy: 1.0000 - val_loss: 0.0997 - val_binary_accuracy: 0.9464
#
# Epoch 00016: val_binary_accuracy did not improve from 0.94643
# Epoch 17/30
# 7/7 [==============================] - 1s 192ms/step - loss: 0.0023 - binary_accuracy: 1.0000 - val_loss: 0.0907 - val_binary_accuracy: 0.9464
#
# Epoch 00017: val_binary_accuracy did not improve from 0.94643
# Epoch 18/30
# 7/7 [==============================] - 1s 178ms/step - loss: 0.0043 - binary_accuracy: 1.0000 - val_loss: 0.0828 - val_binary_accuracy: 0.9464
#
# Epoch 00018: val_binary_accuracy did not improve from 0.94643
# Epoch 19/30
# 7/7 [==============================] - 1s 165ms/step - loss: 0.0025 - binary_accuracy: 1.0000 - val_loss: 0.0779 - val_binary_accuracy: 0.9464
#
# Epoch 00019: val_binary_accuracy did not improve from 0.94643
# Epoch 20/30
# 7/7 [==============================] - 1s 152ms/step - loss: 0.0058 - binary_accuracy: 0.9955 - val_loss: 0.0733 - val_binary_accuracy: 0.9643
#
# Epoch 00020: val_binary_accuracy improved from 0.94643 to 0.96429, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_4.h5
# Epoch 21/30
# 7/7 [==============================] - 1s 158ms/step - loss: 0.0015 - binary_accuracy: 1.0000 - val_loss: 0.0675 - val_binary_accuracy: 0.9643
#
# Epoch 00021: val_binary_accuracy did not improve from 0.96429
# ...
# [[42 10]
#  [ 1 68]]
#
# Normal accuracy: 0.8076923076923077
# Tumor accuracy: 0.9855072463768116
#
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.81      0.88        52
#        Tumor       0.87      0.99      0.93        69
#
#     accuracy                           0.91       121
#    macro avg       0.92      0.90      0.90       121
# weighted avg       0.92      0.91      0.91       121
#
#
# Unweighted Accuracy: 0.9090909090909091
# Weighted Accuracy: 0.8965997770345597
# 4/4 [==============================] - 1s 151ms/step - loss: 0.5721 - binary_accuracy: 0.9339
# Found 224 validated image filenames belonging to 2 classes.
# Found 55 validated image filenames belonging to 2 classes.
# Epoch 1/30
# 7/7 [==============================] - 13s 652ms/step - loss: 5.1640 - binary_accuracy: 0.5580 - val_loss: 6.1752 - val_binary_accuracy: 0.4364
#
# Epoch 00001: val_binary_accuracy improved from -inf to 0.43636, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_5.h5
# Epoch 2/30
# 7/7 [==============================] - 1s 165ms/step - loss: 3.2402 - binary_accuracy: 0.7143 - val_loss: 4.9597 - val_binary_accuracy: 0.5455
#
# Epoch 00002: val_binary_accuracy improved from 0.43636 to 0.54545, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_5.h5
# Epoch 3/30
# 7/7 [==============================] - 1s 188ms/step - loss: 2.5287 - binary_accuracy: 0.7634 - val_loss: 4.0628 - val_binary_accuracy: 0.6909
#
# Epoch 00003: val_binary_accuracy improved from 0.54545 to 0.69091, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_5.h5
# Epoch 4/30
# 7/7 [==============================] - 1s 163ms/step - loss: 1.8674 - binary_accuracy: 0.8393 - val_loss: 2.5838 - val_binary_accuracy: 0.7091
#
# Epoch 00004: val_binary_accuracy improved from 0.69091 to 0.70909, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_5.h5
# Epoch 5/30
# 7/7 [==============================] - 1s 151ms/step - loss: 1.5400 - binary_accuracy: 0.8705 - val_loss: 2.9912 - val_binary_accuracy: 0.7091
#
# Epoch 00005: val_binary_accuracy did not improve from 0.70909
# Epoch 6/30
# 7/7 [==============================] - 1s 160ms/step - loss: 1.0126 - binary_accuracy: 0.9152 - val_loss: 4.5233 - val_binary_accuracy: 0.5273
#
# Epoch 00006: val_binary_accuracy did not improve from 0.70909
# Epoch 7/30
# 7/7 [==============================] - 1s 160ms/step - loss: 0.8065 - binary_accuracy: 0.9241 - val_loss: 4.7929 - val_binary_accuracy: 0.5273
#
# Epoch 00007: val_binary_accuracy did not improve from 0.70909
# Epoch 8/30
# 7/7 [==============================] - 1s 188ms/step - loss: 0.8639 - binary_accuracy: 0.9018 - val_loss: 7.1590 - val_binary_accuracy: 0.4545
#
# Epoch 00008: val_binary_accuracy did not improve from 0.70909
# Epoch 9/30
# 7/7 [==============================] - 1s 163ms/step - loss: 1.0855 - binary_accuracy: 0.9062 - val_loss: 7.1711 - val_binary_accuracy: 0.4364
#
# Epoch 00009: val_binary_accuracy did not improve from 0.70909
# Epoch 10/30
# 7/7 [==============================] - 1s 161ms/step - loss: 0.6642 - binary_accuracy: 0.8795 - val_loss: 6.4998 - val_binary_accuracy: 0.4364
#
# Epoch 00010: val_binary_accuracy did not improve from 0.70909
# Epoch 11/30
# 7/7 [==============================] - 1s 160ms/step - loss: 0.7080 - binary_accuracy: 0.9196 - val_loss: 5.8318 - val_binary_accuracy: 0.5273
#
# Epoch 00011: val_binary_accuracy did not improve from 0.70909
# Epoch 12/30
# 7/7 [==============================] - 1s 161ms/step - loss: 0.3618 - binary_accuracy: 0.9330 - val_loss: 5.0106 - val_binary_accuracy: 0.5636
#
# Epoch 00012: val_binary_accuracy did not improve from 0.70909
# Epoch 13/30
# 7/7 [==============================] - 1s 165ms/step - loss: 0.6721 - binary_accuracy: 0.9286 - val_loss: 4.4076 - val_binary_accuracy: 0.6727
#
# Epoch 00013: val_binary_accuracy did not improve from 0.70909
# Epoch 14/30
# 7/7 [==============================] - 1s 161ms/step - loss: 0.6935 - binary_accuracy: 0.9196 - val_loss: 4.0487 - val_binary_accuracy: 0.6727
#
# Epoch 00014: val_binary_accuracy did not improve from 0.70909
# Epoch 15/30
# 7/7 [==============================] - 1s 162ms/step - loss: 0.4538 - binary_accuracy: 0.9598 - val_loss: 3.2504 - val_binary_accuracy: 0.7091
#
# Epoch 00015: val_binary_accuracy did not improve from 0.70909
# Epoch 16/30
# 7/7 [==============================] - 2s 222ms/step - loss: 0.2110 - binary_accuracy: 0.9598 - val_loss: 2.2604 - val_binary_accuracy: 0.7455
#
# Epoch 00016: val_binary_accuracy improved from 0.70909 to 0.74545, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_5.h5
# Epoch 17/30
# 7/7 [==============================] - 1s 198ms/step - loss: 0.3665 - binary_accuracy: 0.9643 - val_loss: 1.3677 - val_binary_accuracy: 0.7636
#
# Epoch 00017: val_binary_accuracy improved from 0.74545 to 0.76364, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_5.h5
# Epoch 18/30
# 7/7 [==============================] - 1s 155ms/step - loss: 0.4572 - binary_accuracy: 0.9509 - val_loss: 1.0066 - val_binary_accuracy: 0.8727
#
# Epoch 00018: val_binary_accuracy improved from 0.76364 to 0.87273, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_5.h5
# Epoch 19/30
# 7/7 [==============================] - 1s 160ms/step - loss: 0.2401 - binary_accuracy: 0.9643 - val_loss: 0.9318 - val_binary_accuracy: 0.8909
#
# Epoch 00019: val_binary_accuracy improved from 0.87273 to 0.89091, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_5.h5
# Epoch 20/30
# 7/7 [==============================] - 1s 154ms/step - loss: 0.1191 - binary_accuracy: 0.9598 - val_loss: 0.6664 - val_binary_accuracy: 0.9455
#
# Epoch 00020: val_binary_accuracy improved from 0.89091 to 0.94545, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_5.h5
# Epoch 21/30
# 7/7 [==============================] - 1s 160ms/step - loss: 0.2529 - binary_accuracy: 0.9643 - val_loss: 0.6152 - val_binary_accuracy: 0.9455
#
# Epoch 00021: val_binary_accuracy did not improve from 0.94545
# Epoch 22/30
# 7/7 [==============================] - 1s 187ms/step - loss: 0.3870 - binary_accuracy: 0.9509 - val_loss: 0.5925 - val_binary_accuracy: 0.9455
#
# Epoch 00022: val_binary_accuracy did not improve from 0.94545
# Epoch 23/30
# 7/7 [==============================] - 1s 158ms/step - loss: 0.2767 - binary_accuracy: 0.9821 - val_loss: 0.3372 - val_binary_accuracy: 0.9636
#
# Epoch 00023: val_binary_accuracy improved from 0.94545 to 0.96364, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_5.h5
# Epoch 24/30
# 7/7 [==============================] - 1s 157ms/step - loss: 0.2351 - binary_accuracy: 0.9688 - val_loss: 0.3141 - val_binary_accuracy: 0.9636
#
# Epoch 00024: val_binary_accuracy did not improve from 0.96364
# Epoch 25/30
# 7/7 [==============================] - 1s 165ms/step - loss: 0.1514 - binary_accuracy: 0.9866 - val_loss: 0.3045 - val_binary_accuracy: 0.9636
#
# Epoch 00025: val_binary_accuracy did not improve from 0.96364
# Epoch 26/30
# 7/7 [==============================] - 1s 170ms/step - loss: 0.2175 - binary_accuracy: 0.9821 - val_loss: 0.2975 - val_binary_accuracy: 0.9636
#
# Epoch 00026: val_binary_accuracy did not improve from 0.96364
# Epoch 27/30
# 7/7 [==============================] - 1s 176ms/step - loss: 0.2278 - binary_accuracy: 0.9777 - val_loss: 0.2920 - val_binary_accuracy: 0.9818
#
# Epoch 00027: val_binary_accuracy improved from 0.96364 to 0.98182, saving model to /kaggle/working/datasets/01_MRI/Saved_CNN_Models/Testing/transfer_learning_model_dense169_1/AugTest/30epochs/transfer_learning_model_dense169_1_model_5.h5
# Epoch 28/30
# 7/7 [==============================] - 1s 160ms/step - loss: 0.0897 - binary_accuracy: 0.9866 - val_loss: 0.2884 - val_binary_accuracy: 0.9818
#
# Epoch 00028: val_binary_accuracy did not improve from 0.98182
# Epoch 29/30
# 7/7 [==============================] - 1s 165ms/step - loss: 0.0887 - binary_accuracy: 0.9821 - val_loss: 0.2859 - val_binary_accuracy: 0.9818
#
# Epoch 00029: val_binary_accuracy did not improve from 0.98182
# Epoch 30/30
# 7/7 [==============================] - 1s 191ms/step - loss: 0.1552 - binary_accuracy: 0.9821 - val_loss: 0.2841 - val_binary_accuracy: 0.9818
#
# Epoch 00030: val_binary_accuracy did not improve from 0.98182
# <div>                            <div id="22d47fcb-a35f-4746-9c21-a0f4aefcd458" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22d47fcb-a35f-4746-9c21-a0f4aefcd458")) {                    Plotly.newPlot(                        "22d47fcb-a35f-4746-9c21-a0f4aefcd458",                        [{"mode":"lines+markers","name":"Training Accuracy","y":[0.5580357313156128,0.7142857313156128,0.7633928656578064,0.8392857313156128,0.8705357313156128,0.9151785969734192,0.9241071343421936,0.9017857313156128,0.90625,0.8794642686843872,0.9196428656578064,0.9330357313156128,0.9285714030265808,0.9196428656578064,0.9598214030265808,0.9598214030265808,0.9642857313156128,0.9508928656578064,0.9642857313156128,0.9598214030265808,0.9642857313156128,0.9508928656578064,0.9821428656578064,0.96875,0.9866071343421936,0.9821428656578064,0.9776785969734192,0.9866071343421936,0.9821428656578064,0.9821428656578064],"type":"scatter"},{"mode":"lines+markers","name":"Validation Accuracy","y":[0.4363636374473572,0.5454545617103577,0.6909090876579285,0.7090908885002136,0.7090908885002136,0.5272727012634277,0.5272727012634277,0.4545454680919647,0.4363636374473572,0.4363636374473572,0.5272727012634277,0.5636363625526428,0.6727272868156433,0.6727272868156433,0.7090908885002136,0.7454545497894287,0.7636363506317139,0.8727272748947144,0.8909090757369995,0.9454545378684998,0.9454545378684998,0.9454545378684998,0.9636363387107849,0.9636363387107849,0.9636363387107849,0.9636363387107849,0.9818181991577148,0.9818181991577148,0.9818181991577148,0.9818181991577148],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111," ...
# [[47  5]
#  [ 6 63]]
#
# Normal accuracy: 0.9038461538461539
# Tumor accuracy: 0.9130434782608695
#
#               precision    recall  f1-score   support
#
#       Normal       0.89      0.90      0.90        52
#        Tumor       0.93      0.91      0.92        69
#
#     accuracy                           0.91       121
#    macro avg       0.91      0.91      0.91       121
# weighted avg       0.91      0.91      0.91       121
#
#
# Unweighted Accuracy: 0.9090909090909091
# Weighted Accuracy: 0.9084448160535117
# 4/4 [==============================] - 1s 105ms/step - loss: 0.9598 - binary_accuracy: 0.9008
